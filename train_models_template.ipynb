# %%
# Clone repository if not cloned already
# !git clone https://github.com/Bryanlee99/pix2pix_cyclegan_guess_noise.git

# %%
# Change to correct directory
import os
os.chdir('pix2pix_cyclegan_guess_noise')

# %%
# Activates pytorch source from deeplearning AMI; Install required packages and downgrade scipy to have imresize 
# !source activate pytorch_p36
# !pip install tensorboard
# !pip install -r requirements.txt
# !pip install scipy==1.1.0 --user
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/40/23/53ffe290341cd0855d595b0a2e7485932f473798af173bbe3a584b99bb06/tensorboard-2.1.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/54/31/f944cbd5bdbcc90d5b36f0615036308c8ec1e41b4788da5b55d4900f6803/google_auth-1.8.2-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# ...
#      |████████████████████████████████| 2.4MB 31.1MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl
# ...

# %%
# Remove line breaks to run .sh command to download map files (run these in the terminal, jupyter can't accept with 'y')
#!sudo yum install dos2unix
# !dos2unix ./datasets/download_cyclegan_dataset.sh 
# !bash ./datasets/download_cyclegan_dataset.sh maps
# Out:
# dos2unix: converting file ./datasets/download_cyclegan_dataset.sh to UNIX format ...
# Specified [maps]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2019-12-15 02:18:36--  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/maps.zip
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1476754427 (1.4G) [application/zip]
# Saving to: ‘./datasets/maps.zip’
#
# ./datasets/maps.zip   7%[>                   ] 105.57M  22.3MB/s    eta 63s    ^C

# %%
# Train
# !python train.py --dataroot ./datasets/maps --model cycle_gan_guess_noisy --lambda_guess 1 --noise_std 0.06 --name cycle_gan_guess_noisy --batch_size 2 --display_id 0
# Out:
# ----------------- Options ---------------
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/maps               	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %%
# Test
# !python test.py --dataroot ./datasets/maps --name experiment_name --model cycle_gan_guess_noisy --direction BtoA

# %%
from torch.utils.tensorboard import SummaryWriter

# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('runs/fashion_mnist_experiment_1')
